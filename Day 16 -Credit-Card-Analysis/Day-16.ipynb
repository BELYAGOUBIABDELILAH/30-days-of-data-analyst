# %% [markdown]
# # Hello everyone its day 16  Today I have data of  Credit Card Spending Habits in Various cities of india

# %% [markdown]
# # Data_Cleaning

# %%
## import libraries 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
##red data useing csv
data=pd.read_csv("Credit card transactions - India - Simple.csv")

##drop index column 
data.drop(columns=['index'],inplace=True)

## first five rows of data
data.head()
# Out:
#                     City       Date  Card Type Exp Type Gender  Amount
# 0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %%
data.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26052 entries, 0 to 26051
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       26052 non-null  object
#  1   Date       26052 non-null  object
#  2   Card Type  26052 non-null  object
#  3   Exp Type   26052 non-null  object
#  4   Gender     26052 non-null  object
#  5   Amount     26052 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#               Amount
# count   26052.000000
# mean   156411.537425
# std    103063.254287
# min      1005.000000
# 25%     77120.250000
# 50%    153106.500000
# 75%    228050.000000
# max    998077.000000

# %%
data.isnull().sum()
# Out:
# City         0
# Date         0
# Card Type    0
# Exp Type     0
# Gender       0
# Amount       0
# dtype: int64

# %%
data[['day','month','year']]=data['Date'].str.split('-' , expand=True)

# %%
# defineing a function to clasify the purchase price 
def purchase_range(amount):
    if amount<=1000:
        amt='less then 1000'
    elif amount>1000 and amount <=5000:
        amt='less then 5000'
    elif amount >5000 and amount<=10000:
        amt='less then 10000'
    elif amount >10000 and amount <=15000:
        amt='less then 15000'
    else:
        amt='greter then 15000'
    return amt 

##apply function 
data['amount_category']=data.Amount.apply(purchase_range)


##view data
data.head()
# Out:
#                     City       Date  Card Type Exp Type Gender  Amount day  \
# 0           Delhi, India  29-Oct-14       Gold    Bills      F   82475  29
# 1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555  22
# 2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738  27
# 3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424  12
# 4       Bengaluru, India   5-May-15       Gold    Bills      F  171574   5
#
#   month year    amount_category
# 0   Oct   14  greter then 15000
# 1   Aug   14  greter then 15000
# 2   Aug   14  greter then 15000
# 3   Apr   14  greter then 15000
# 4   May   15  greter then 15000

# %% [markdown]
# # EDA

# %% [markdown]
# # Countplot of card type

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=data,x='Card Type')
plt.show()

# %% [markdown]
# countplot of expansive type

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data,x='Exp Type')
plt.show()

# %% [markdown]
# cheaking expansive type with  gender use

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data,x='Exp Type',hue='Gender')
plt.show()

# %% [markdown]
# cheaking card type gender wise

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data,x='Card Type',hue='Gender')
plt.show()

# %% [markdown]
# cheaking amount spend monthly

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=data,x='month',y='Amount')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=data,x='month',y='Amount')
plt.show()

# %% [markdown]
# voilin plot of card amount

# %%
plt.plot(figsize=(15,5))
sns.violinplot(data=data,x='Card Type',y='Amount',box=True, points="all")
# Out:
# <AxesSubplot: xlabel='Card Type', ylabel='Amount'>

# %% [markdown]
# plot pie chart of amount and card type

# %%
fig8 = px.pie(data, values='Amount', names='Card Type')
fig8.show()
# Out:
# <div>                            <div id="a134952e-b15d-4997-9cfd-c77ca47b4ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a134952e-b15d-4997-9cfd-c77ca47b4ef2")) {                    Plotly.newPlot(                        "a134952e-b15d-4997-9cfd-c77ca47b4ef2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Card Type=%{label}<br>Amount=%{value}<extra></extra>","labels":["Gold","Platinum","Silver","Signature","Gold","Silver","Gold","Platinum","Silver","Platinum","Platinum","Signature","Gold","Signature","Signature","Platinum","Signature","Gold","Platinum","Platinum","Signature","Signature","Silver","Gold","Gold","Silver","Platinum","Signature","Platinum","Gold","Signature","Gold","Platinum","Gold","Signature","Platinum","Signature","Silver","Platinum","Silver","Platinum","Gold","Platinum","Silver","Platinum","Gold","Gold","Platinum","Gold","Signature","Signature","Platinum","Signature","Signature","Signature","Silver","Signature","Platinum","Platinum","Silver","Platinum","Platinum","Platinum","Signature","Platinum","Platinum","Gold","Platinum","Gold","Gold","Gold","Silver","Signature","Platinum","Silver","Platinum","Gold","Platinum","Silver","Platinum","Platinum","Silver","Platinum","Signature","Gold","Silver","Gold","Silver","Gold","Gold","Gold","Signature","Platinum","Gold","Gold","Gold","Gold","Signature","Silver","Signature","Platinum","Signature","Silver","Signature","Silver","Platinum","Signature","Signature","Gold","Signature","Signature","Gold","Silver","Platinum","Silver","Platinum","Platinum","Signature","Platinum","Platinum","Gold","Silver","Gold","Signature","Gold","Platinum","Signature","Gold","Gold","Silver","Platinum","Gold","Silver","Platinum","Gold","Signature","Gold","Silver","Silver","Gold","Silver","Gold","Gold","Silver","Signature","Signature","Signature","Signature","Silver","Signature","Signature","Gold","Gold","Signature","Silver","Platinum","Gold","Silver","Gold","Silver","Silver","Signature","Gold","Platinum","Silver","Gold","Signature","Signature","Platinum","Platinum","Platinum","Silver","Gold","Platinum","Signature","Gold","Signature","Silver","Signature","Platinum","Silver","Gold","Signature","Platinum","Signature","Platinum","Gold","Gold","Gold","Gold","Platinum","Silver","Silver","Gold","Signature","Silver","Silver","Platinum","Platinum","Platinum","Signature","Platinum","Gold","Silver","Gold","Signature","Silver","Signature","Silver","Platinum","Gold","Signature","Signature","Signature","Signature","Platinum","Signature","Signature","Signature","Silver","Platinum","Silver","Silver","Gold","Silver","Gold","Gold","Silver","Signature","Platinum","Signature","Gold","Signature","Signature","Gold","Signature","Signature","Gold","Silver","Platinum","Gold","Gold","Platinum","Silver","Platinum","Platinum","Platinum","Signature","Signature","Gold","Platinum","Platinum","Gold","Platinum","Gold","Platinum","Gold","Signature","Silver","Silver","Silver","Platinum","Signature","Signature","Gold","Gold","Gold","Gold","Gold","Platinum","Silver","Gold","Platinum","Signature","Gold","Silver","Platinum","Silver","Silver","Gold","Gold","Silver","Silver","Platinum","Silver","Platinum","Silver","Signature","Silver","Signature","Gold","Platinum","Platinum","Signature","Silver","Gold","Signature","Platinum","Signature","Gold","Platinum","Silver","Signature","Signature","Signature","Platinum","Silver","Signature","Silver","Silver","Signature","Gold","Platinum","Gold","Platinum","Platinum","Silver","Signature","Platinum","Signature","Signature","Signature","Signature","Platinum","Platinum","Signature","Gold","Platinum","Gold","Gold","Signature","Silver","Signature","Signature","Gold","Signature","Silver","Signature","Platinum","Silver","Platinum"," ...

# %% [markdown]
# pie plot of amount and gender

# %%
fig=px.pie(data,values='Amount',names='Gender')

fig.show()
# Out:
# <div>                            <div id="28e7b3e2-0d62-4b09-86b6-55bf20be5fb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28e7b3e2-0d62-4b09-86b6-55bf20be5fb2")) {                    Plotly.newPlot(                        "28e7b3e2-0d62-4b09-86b6-55bf20be5fb2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Gender=%{label}<br>Amount=%{value}<extra></extra>","labels":["F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F","F" ...

# %% [markdown]
# pie plot of expanse and amount

# %%
fig=px.pie(data,values='Amount',names='Exp Type')
fig.show()
# Out:
# <div>                            <div id="8b6ac121-4e8d-4067-9145-9ff5bbc497ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b6ac121-4e8d-4067-9145-9ff5bbc497ce")) {                    Plotly.newPlot(                        "8b6ac121-4e8d-4067-9145-9ff5bbc497ce",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Exp Type=%{label}<br>Amount=%{value}<extra></extra>","labels":["Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bills","Bill ...

# %% [markdown]
# # Distribution Plot Of Amount And Year

# %%
plt.figure(figsize=(15,8))
sns.displot(data=data,x='Amount',hue='year',kind='kde')
plt.show()

# %% [markdown]
# # Distribution of Amount and Card type

# %%
plt.figure(figsize=(15,8))
sns.displot(data=data,x='Amount',hue='Card Type',kind='kde')
plt.show()

# %% [markdown]
# # Distribution of Amount And Month

# %%
plt.figure(figsize=(15,8))
sns.displot(data=data,x='Amount',hue='month',kind='kde')
plt.show()

# %% [markdown]
# # Model Building and Spilit Data into Category

# %%
##label encodeing and drop date column 
data['City']=LabelEncoder().fit_transform(data['City'])
data['Card Type']=LabelEncoder().fit_transform(data['Card Type'])
data['Exp Type']=LabelEncoder().fit_transform(data['Exp Type'])
data['Gender']=LabelEncoder().fit_transform(data['Gender'])
data['month']=LabelEncoder().fit_transform(data['month'])
data['amount_category']=LabelEncoder().fit_transform(data['amount_category'])
data.drop(columns='Date',inplace=True)

# %%
x=data[['City', 'Card Type', 'Exp Type', 'Gender', 
       'year','month']]
y=data['amount_category']

# %%
## split data into train and test 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((20841, 6), (5211, 6), (20841,), (5211,))

# %%
models = {}
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
predicted=lr_model.predict(x_test)
conf = confusion_matrix(y_test, predicted)
print ("Confusion Matrix : \n", conf)
print()
print()
print ("The accuracy of Logistic Regression is : ", accuracy_score(y_test, predicted)*100, "%")
models['logistic_regression'] = accuracy_score(y_test, predicted)*100
# Out:
# Confusion Matrix :
#  [[4984    0    0    0]
#  [  82    0    0    0]
#  [  72    0    0    0]
#  [  73    0    0    0]]
#
#
# The accuracy of Logistic Regression is :  95.64383035885626 %
# C:\Users\kabir\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
gnb_model = GaussianNB()
gnb_model.fit(x_train, y_train)
  
predicted = gnb_model.predict(x_test)
  
print("The accuracy of Gaussian Naive Bayes model is : ", accuracy_score(y_test, predicted)*100, "%")
models['Gaussian_Naive_Bayes'] = accuracy_score(y_test, predicted)*100
# Out:
# The accuracy of Gaussian Naive Bayes model is :  95.64383035885626 %

# %%
bnb_model = BernoulliNB()
bnb_model.fit(x_train, y_train)
  
predicted = bnb_model.predict(x_test)
  
print("The accuracy of Gaussian Naive Bayes model is : ", accuracy_score(y_test, predicted)*100, "%")
models['Bernoulli_Naive_Bayes'] = accuracy_score(y_test, predicted)*100
# Out:
# The accuracy of Gaussian Naive Bayes model is :  95.64383035885626 %

# %%
svm_model = SVC()
svm_model.fit(x_train, y_train)
  
predicted = svm_model.predict(x_test)
print("The accuracy of SVM is : ", accuracy_score(y_test, predicted)*100, "%")
models['svm'] = accuracy_score(y_test, predicted)*100
# Out:
# The accuracy of SVM is :  95.64383035885626 %

# %%
knn_model = KNeighborsClassifier(n_neighbors = 1)  
knn_model.fit(x_train, y_train)
predicted = knn_model.predict(x_test)
  

print(confusion_matrix(y_test, predicted))
print("The accuracy of KNN is : ", accuracy_score(y_test, predicted)*100, "%")
models['knn'] = accuracy_score(y_test, predicted)*100
# Out:
# [[4757   76   71   80]
#  [  80    0    0    2]
#  [  68    1    2    1]
#  [  66    0    4    3]]
# The accuracy of KNN is :  91.38361159086547 %

# %%
# Optimizing KNN
error_rate = []
  
for i in range(1, 40):
      
    model = KNeighborsClassifier(n_neighbors = i)
    model.fit(x_train, y_train)
    pred_i = model.predict(x_test)
    error_rate.append(np.mean(pred_i != y_test))
  
plt.figure(figsize =(10, 6))
plt.plot(range(1, 40), error_rate, color ='blue',
                linestyle ='dashed', marker ='o',
         markerfacecolor ='red', markersize = 10)
  
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
# k = 6
knn_o_model = KNeighborsClassifier(n_neighbors = 6)
  
knn_o_model.fit(x_train, y_train)
predicted = knn_o_model.predict(x_test)
  
print('Confusion Matrix :')
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, predicted))

print()
print()
print("The accuracy of KNN is : ", accuracy_score(y_test, predicted)*100, "%")
models['Optimized_knn'] = accuracy_score(y_test, predicted)*100
# Out:
# Confusion Matrix :
# [[4984    0    0    0]
#  [  82    0    0    0]
#  [  72    0    0    0]
#  [  73    0    0    0]]
#
#
# The accuracy of KNN is :  95.64383035885626 %

# %%
xgb_model = xgb.XGBClassifier(use_label_encoder=False)
xgb_model.fit(x_train, y_train)
   
predicted = xgb_model.predict(x_test)
   
cm = confusion_matrix(y_test, predicted)
print()
print ("The accuracy of X Gradient Boosting is : ", accuracy_score(y_test, predicted)*100, "%")
models['X_Gradient_Boosting'] = accuracy_score(y_test, predicted)*100
# Out:
# C:\Users\kabir\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1395: UserWarning:
#
# `use_label_encoder` is deprecated in 1.7.0.
# The accuracy of X Gradient Boosting is :  95.64383035885626 %

# %%
rf_model = RandomForestRegressor(n_estimators = 100, random_state = 0)  
rf_model.fit(x_train, y_train)  
predicted = rf_model.predict(x_test)
print("The accuracy of Random Forest is : ", accuracy_score(y_test, predicted.round())*100, "%")
models['random_forest'] = accuracy_score(y_test, predicted.round())*100
# Out:
# The accuracy of Random Forest is :  90.07867971598542 %

# %%
for model in models:
    print(str(model)," : ",str(models[model]))
# Out:
# logistic_regression  :  95.64383035885626
# Gaussian_Naive_Bayes  :  95.64383035885626
# Bernoulli_Naive_Bayes  :  95.64383035885626
# svm  :  95.64383035885626
# knn  :  91.38361159086547
# Optimized_knn  :  95.64383035885626
# X_Gradient_Boosting  :  95.64383035885626
# random_forest  :  90.07867971598542

# %%
model_keys = models.keys()
model_values = models.values()

# %%
fig = px.histogram(x=model_keys, 
             y=model_values,
             color=model_keys,
             title='Models v/s Accuracy'
            )
fig.show()
# Out:
# <div>                            <div id="be8b17bf-8c07-487b-b5a9-13abba8a39d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be8b17bf-8c07-487b-b5a9-13abba8a39d7")) {                    Plotly.newPlot(                        "be8b17bf-8c07-487b-b5a9-13abba8a39d7",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=logistic_regression<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"logistic_regression","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"logistic_regression","offsetgroup":"logistic_regression","orientation":"v","showlegend":true,"x":["logistic_regression"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Gaussian_Naive_Bayes<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Gaussian_Naive_Bayes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Gaussian_Naive_Bayes","offsetgroup":"Gaussian_Naive_Bayes","orientation":"v","showlegend":true,"x":["Gaussian_Naive_Bayes"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Bernoulli_Naive_Bayes<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Bernoulli_Naive_Bayes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bernoulli_Naive_Bayes","offsetgroup":"Bernoulli_Naive_Bayes","orientation":"v","showlegend":true,"x":["Bernoulli_Naive_Bayes"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=svm<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"svm","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"svm","offsetgroup":"svm","orientation":"v","showlegend":true,"x":["svm"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=knn<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"knn","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"knn","offsetgroup":"knn","orientation":"v","showlegend":true,"x":["knn"],"xaxis":"x","y":[91.38361159086547],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Optimized_knn<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Optimized_knn","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Optimized_knn","offsetgroup":"Optimized_knn","orientation":"v","showlegend":true,"x":["Optimized_knn"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=X_Gradient_Boosting<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"X_Gradient_Boosting","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"X_Gradient_Boosting","offsetgroup":"X_Gradient_Boosting","orientation":"v","showlegend":true,"x":["X_Gradient_Boosting"],"xaxis":"x","y":[95.64383035885626],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=random_forest<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"random_forest","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"random_forest","offsetgroup":"random_forest","orientation":"v","showlegend":true,"x":["random_forest"],"xaxis":"x","y":[90.07867971598542],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %% [markdown]
# # Thanks for reading till the end ! If you liked the  EDA, Model Training, Model Evaluation and Comparison, Predtictions  pls do Upvote👍 and give some remarks/advice if you feels some things need to be added
